# %% [markdown]
# ## Neat Sequencing barcode scheme
#
# How would you tag ~100,000 molecular biology samples with unique barcodes?
#
# One way to do it would be to assign two different barcodes, $A$ and $B$, to each sample.
#
# Let's say the barcodes have to fit on a single 384-well plate. This way, we have 192 $A$ barcodes and 192 $B$ barcodes, and the total number of samples we can uniquely barcode is $192 \times 192 = 36,864$, which is a pretty good number for a PacBio run, which will provide about 10 times that many consensus reads, giving us 10X coverage in the ideal case.

# %%
import numpy as np
import pandas
from itertools import product

# %%
barcodes_A = [ 'A{0:03d}'.format( i ) for i in range( 192 ) ] 
barcodes_B = [ 'B{0:03d}'.format( i ) for i in range( 192 ) ] 
barcodes = product( barcodes_A, barcodes_B )

# %% [markdown]
# Plates come in with a variable number of samples. Here, we assume that all plates have at least 5 samples. We're going to assume that they're all 384-well plates, because those are the only kind we sell ;)

# %%
n_plates = 30
plates = [ range( np.random.randint( 5, 384 ) ) for i in range( n_plates ) ] 
plates
# Out:
# [range(0, 92),
#  range(0, 345),
#  range(0, 215),
#  range(0, 354),
#  range(0, 63),
#  range(0, 273),
#  range(0, 121),
#  range(0, 69),
#  range(0, 63),
#  range(0, 122),
#  range(0, 290),
#  range(0, 375),
#  range(0, 167),
#  range(0, 201),
#  range(0, 57),
#  range(0, 229),
#  range(0, 200),
#  range(0, 14),
#  range(0, 219),
#  range(0, 89),
#  range(0, 47),
#  range(0, 63),
#  range(0, 325),
#  range(0, 58),
#  range(0, 218),
#  range(0, 186),
#  range(0, 296),
#  range(0, 24),
#  range(0, 313),
#  range(0, 267)]

# %%
df = pandas.DataFrame(None, columns=['plate_index', 'well_index', 'barcode_A', 'barcode_B'])
counter = 0 
for plate_index, plate in enumerate( plates ):
    for well_index, well in enumerate( plate ): 
        barcode_A, barcode_B = next( barcodes ) 
        df.loc[ counter ] = ( plate_index, well_index, barcode_A, barcode_B ) 
        counter += 1 
df
# Out:
#       plate_index  well_index barcode_A barcode_B
# 0             0.0         0.0      A000      B000
# 1             0.0         1.0      A000      B001
# 2             0.0         2.0      A000      B002
# 3             0.0         3.0      A000      B003
# 4             0.0         4.0      A000      B004
# 5             0.0         5.0      A000      B005
# 6             0.0         6.0      A000      B006
# 7             0.0         7.0      A000      B007
# 8             0.0         8.0      A000      B008
# 9             0.0         9.0      A000      B009
# 10            0.0        10.0      A000      B010
# 11            0.0        11.0      A000      B011
# 12            0.0        12.0      A000      B012
# 13            0.0        13.0      A000      B013
# 14            0.0        14.0      A000      B014
# 15            0.0        15.0      A000      B015
# 16            0.0        16.0      A000      B016
# 17            0.0        17.0      A000      B017
# 18            0.0        18.0      A000      B018
# 19            0.0        19.0      A000      B019
# 20            0.0        20.0      A000      B020
# 21            0.0        21.0      A000      B021
# 22            0.0        22.0      A000      B022
# 23            0.0        23.0      A000      B023
# 24            0.0        24.0      A000      B024
# 25            0.0        25.0      A000      B025
# 26            0.0        26.0      A000      B026
# 27            0.0        27.0      A000      B027
# 28            0.0        28.0      A000      B028
# 29            0.0        29.0      A000      B029
# ...           ...         ...       ...       ...
# 5325         29.0       237.0      A027      B141
# 5326         29.0       238.0      A027      B142
# 5327         29.0       239.0      A027      B143
# 5328         29.0       240.0      A027      B144
# 5329         29.0       241.0      A027      B145
# 5330         29.0       242.0      A027      B146
# 5331         29.0       243.0      A027      B147
# 5332         29.0       244.0      A027      B148
# 5333         29.0       245.0      A027      B149
# 5334         29.0       246.0      A027      B150
# 5335         29.0       247.0      A027      B151
# 5336         29.0       248.0      A027      B152
# 5337         29.0       249.0      A027      B153
# 5338         29.0       250.0      A027      B154
# 5339         29.0       251.0      A027      B155
# 5340         29.0       252.0      A027      B156
# 5341         29.0       253.0      A027      B157
# 5342         29.0       254.0      A027      B158
# 5343         29.0       255.0      A027      B159
# 5344         29.0       256.0      A027      B160
# 5345         29.0       257.0      A027      B161
# 5346         29.0       258.0      A027      B162
# 5347         29.0       259.0      A027      B163
# 5348         29.0       260.0      A027      B164
# 5349         29.0       261.0      A027      B165
# 5350         29.0       262.0      A027      B166
# 5351         29.0       263.0      A027      B167
# 5352         29.0       264.0      A027      B168
# 5353         29.0       265.0      A027      B169
# 5354         29.0       266.0      A027      B170
#
# [5355 rows x 4 columns]

# %%
# do all the pipet steps for A 

# groupby plate first! 

sorted_by_A = df.sort_values( by='barcode_A' ) 

for i, row in sorted_by_A.iterrows():
    print( 'Transfer 1.0 µL from barcode_plate {} to well {}'.format( row.barcode_A, row.well_index ) ) 

# do all the pipet steps for B 

sorted_by_B = df.sort_values( by='barcode_B' ) 

for i, row in sorted_by_B.iterrows():
    pass # do the pipet
# Out:
# Transfer 1.0 µL from barcode_plate A000 to well 0.0
# Transfer 1.0 µL from barcode_plate A000 to well 30.0
# Transfer 1.0 µL from barcode_plate A000 to well 31.0
# Transfer 1.0 µL from barcode_plate A000 to well 32.0
# Transfer 1.0 µL from barcode_plate A000 to well 33.0
# Transfer 1.0 µL from barcode_plate A000 to well 34.0
# Transfer 1.0 µL from barcode_plate A000 to well 35.0
# Transfer 1.0 µL from barcode_plate A000 to well 36.0
# Transfer 1.0 µL from barcode_plate A000 to well 37.0
# Transfer 1.0 µL from barcode_plate A000 to well 38.0
# Transfer 1.0 µL from barcode_plate A000 to well 29.0
# Transfer 1.0 µL from barcode_plate A000 to well 39.0
# Transfer 1.0 µL from barcode_plate A000 to well 41.0
# Transfer 1.0 µL from barcode_plate A000 to well 42.0
# Transfer 1.0 µL from barcode_plate A000 to well 43.0
# Transfer 1.0 µL from barcode_plate A000 to well 44.0
# Transfer 1.0 µL from barcode_plate A000 to well 45.0
# Transfer 1.0 µL from barcode_plate A000 to well 46.0
# Transfer 1.0 µL from barcode_plate A000 to well 47.0
# Transfer 1.0 µL from barcode_plate A000 to well 48.0
# Transfer 1.0 µL from barcode_plate A000 to well 49.0
# Transfer 1.0 µL from barcode_plate A000 to well 40.0
# Transfer 1.0 µL from barcode_plate A000 to well 50.0
# Transfer 1.0 µL from barcode_plate A000 to well 28.0
# Transfer 1.0 µL from barcode_plate A000 to well 26.0
# Transfer 1.0 µL from barcode_plate A000 to well 6.0
# Transfer 1.0 µL from barcode_plate A000 to well 7.0
# Transfer 1.0 µL from barcode_plate A000 to well 8.0
# Transfer 1.0 µL from barcode_plate A000 to well 9.0
# Transfer 1.0 µL from barcode_plate A000 to well 10.0
# Transfer 1.0 µL from barcode_plate A000 to well 11.0
# Transfer 1.0 µL from barcode_plate A000 to well 12.0
# Transfer 1.0 µL from barcode_plate A000 to well 13.0
# Transfer 1.0 µL from barcode_plate A000 to well 14.0
# Transfer 1.0 µL from barcode_plate A000 to well 27.0
# Transfer 1.0 µL from barcode_plate A000 to well 15.0
# Transfer 1.0 µL from barcode_plate A000 to well 17.0
# Transfer 1.0 µL from barcode_plate A000 to well 18.0
# Transfer 1.0 µL from barcode_plate A000 to well 19.0
# Transfer 1.0 µL from barcode_plate A000 to well 20.0
# Transfer 1.0 µL from barcode_plate A000 to well 21.0
# Transfer 1.0 µL from barcode_plate A000 to well 22.0
# Transfer 1.0 µL from barcode_plate A000 to well 23.0
# Transfer 1.0 µL from barcode_plate A000 to well 24.0
# Transfer 1.0 µL from barcode_plate A000 to well 25.0
# Transfer 1.0 µL from barcode_plate A000 to well 16.0
# Transfer 1.0 µL from barcode_plate A000 to well 52.0
# Transfer 1.0 µL from barcode_plate A000 to well 53.0
# Transfer 1.0 µL from barcode_plate A000 to well 54.0
# Transfer 1.0 µL from barcode_plate A000 to well 80.0
# Transfer 1.0 µL from barcode_plate A000 to well 81.0
# Transfer 1.0 µL from barcode_plate A000 to well 82.0
# Transfer 1.0 µL from barcode_plate A000 to well 83.0
# Transfer 1.0 µL from barcode_plate A000 to well 84.0
# Transfer 1.0 µL from barcode_plate A000 to well 85.0
# Transfer 1.0 µL from barcode_plate A000 to well 86.0
# Transfer 1.0 µL from barcode_plate A000 to well 87.0
# Transfer 1.0 µL from barcode_plate A000 to well 88.0
# Transfer 1.0 µL from barcode_plate A000 to well 79.0
# Transfer 1.0 µL from barcode_plate A000 to well 89.0
# Transfer 1.0 µL from barcode_plate A000 to well 91.0
# Transfer 1.0 µL from barcode_plate A000 to well 92.0
# Transfer 1.0 µL from barcode_plate A000 to well 93.0
# Transfer 1.0 µL from barcode_plate A000 to well 94.0
# Transfer 1.0 µL from barcode_plate A000 to well 95.0
# Transfer 1.0 µL from barcode_plate A000 to well 96.0
# Transfer 1.0 µL from barcode_plate A000 to well 97.0
# Transfer 1.0 µL from barcode_plate A000 to well 98.0
# Transfer 1.0 µL from barcode_plate A000 to well 99.0
# Transfer 1.0 µL from barcode_plate A000 to well 90.0
# Transfer 1.0 µL from barcode_plate A000 to well 78.0
# Transfer 1.0 µL from barcode_plate A000 to well 77.0
# Transfer 1.0 µL from barcode_plate A000 to well 76.0
# Transfer 1.0 µL from barcode_plate A000 to well 55.0
# Transfer 1.0 µL from barcode_plate A000 to well 56.0
# Transfer 1.0 µL from barcode_plate A000 to well 57.0
# Transfer 1.0 µL from barcode_plate A000 to well 58.0
# Transfer 1.0 µL from barcode_plate A000 to well 59.0
# Transfer 1.0 µL from barcode_plate A000 to well 60.0
# Transfer 1.0 µL from barcode_plate A000 to well 61.0
# Transfer 1.0 µL from barcode_plate A000 to well 62.0
# Transfer 1.0 µL from barcode_plate A000 to well 63.0
# Transfer 1.0 µL from barcode_plate A000 to well 64.0
# Transfer 1.0 µL from barcode_plate A000 to well 65.0
# Transfer 1.0 µL from barcode_plate A000 to well 66.0
# Transfer 1.0 µL from barcode_plate A000 to well 67.0
# Transfer 1.0 µL from barcode_plate A000 to well 68.0
# Transfer 1.0 µL from barcode_plate A000 to well 69.0
# Transfer 1.0 µL from barcode_plate A000 to well 70.0
# Transfer 1.0 µL from barcode_plate A000 to well 71.0
# Transfer 1.0 µL from barcode_plate A000 to well 72.0
# Transfer 1.0 µL from barcode_plate A000 to well 73.0
# Transfer 1.0 µL from barcode_plate A000 to well 74.0
# Transfer 1.0 µL from barcode_plate A000 to well 75.0
# Transfer 1.0 µL from barcode_plate A000 to well 5.0
# Transfer 1.0 µL from barcode_plate A000 to well 4.0
# Transfer 1.0 µL from barcode_plate A000 to well 51.0
# Transfer 1.0 µL from barcode_plate A000 to well 2.0
# Transfer 1.0 µL from barcode_plate A000 to well 26.0
# Transfer 1.0 µL from barcode_plate A000 to well 27.0
# Transfer 1.0 µL from barcode_plate A000 to well 28.0
# Transfer 1.0 µL from barcode_plate A000 to well 29.0
# Transfer 1.0 µL from barcode_plate A000 to well 30.0
# Transfer 1.0 µL from barcode_plate A000 to well 31.0
# Transfer 1.0 µL from barcode_plate A000 to well 32.0
# Transfer 1.0 µL from barcode_plate A000 to well 33.0
# Transfer 1.0 µL from barcode_plate A000 to well 34.0
# Transfer 1.0 µL from barcode_plate A000 to well 25.0
# Transfer 1.0 µL from barcode_plate A000 to well 35.0
# Transfer 1.0 µL from barcode_plate A000 to well 37.0
# Transfer 1.0 µL from barcode_plate A000 to well 38.0
# Transfer 1.0 µL from barcode_plate A000 to well 39.0
# Transfer 1.0 µL from barcode_plate A000 to well 40.0
# Transfer 1.0 µL from barcode_plate A000 to well 41.0
# Transfer 1.0 µL from barcode_plate A000 to well 42.0
# Transfer 1.0 µL from barcode_plate A000 to well 43.0
# Transfer 1.0 µL from barcode_plate A000 to well 44.0
# Transfer 1.0 µL from barcode_plate A000 to well 45.0
# Transfer 1.0 µL from barcode_plate A000 to well 36.0
# Transfer 1.0 µL from barcode_plate A000 to well 24.0
# Transfer 1.0 µL from barcode_plate A000 to well 23.0
# Transfer 1.0 µL from barcode_plate A000 to well 22.0
# Transfer 1.0 µL from barcode_plate A000 to well 3.0
# Transfer 1.0 µL from barcode_plate A000 to well 2.0
# Transfer 1.0 µL from barcode_plate A000 to well 3.0
# Transfer 1.0 µL from barcode_plate A000 to well 4.0
# Transfer 1.0 µL from barcode_plate A000 to well 5.0
# Transfer 1.0 µL from barcode_plate A000 to well 6.0
# Transfer 1.0 µL from barcode_plate A000 to well 7.0
# Transfer 1.0 µL from barcode_plate A000 to well 8.0
# Transfer 1.0 µL from barcode_plate A000 to well 9.0
# Transfer 1.0 µL from barcode_plate A000 to well 10.0
# Transfer 1.0 µL from barcode_plate A000 to well 11.0
# Transfer 1.0 µL from barcode_plate A000 to well 12.0
# Transfer 1.0 µL from barcode_plate A000 to well 13.0
# Transfer 1.0 µL from barcode_plate A000 to well 14.0
# Transfer 1.0 µL from barcode_plate A000 to well 15.0
# Transfer 1.0 µL from barcode_plate A000 to well 16.0
# Transfer 1.0 µL from barcode_plate A000 to well 17.0
# Transfer 1.0 µL from barcode_plate A000 to well 18.0
# Transfer 1.0 µL from barcode_plate A000 to well 19.0
# Transfer 1.0 µL from barcode_plate A000 to well 20.0
# Transfer 1.0 µL from barcode_plate A000 to well 21.0
# Transfer 1.0 µL from barcode_plate A000 to well 46.0
# Transfer 1.0 µL from barcode_plate A000 to well 47.0
# Transfer 1.0 µL from barcode_plate A000 to well 1.0
# Transfer 1.0 µL from barcode_plate A000 to well 81.0
# Transfer 1.0 µL from barcode_plate A000 to well 73.0
# Transfer 1.0 µL from barcode_plate A000 to well 74.0
# Transfer 1.0 µL from barcode_plate A000 to well 76.0
# Transfer 1.0 µL from barcode_plate A000 to well 77.0
# Transfer 1.0 µL from barcode_plate A000 to well 78.0
# Transfer 1.0 µL from barcode_plate A000 to well 79.0
# Transfer 1.0 µL from barcode_plate A000 to well 80.0
# Transfer 1.0 µL from barcode_plate A000 to well 48.0
# Transfer 1.0 µL from barcode_plate A000 to well 82.0
# Transfer 1.0 µL from barcode_plate A000 to well 72.0
# Transfer 1.0 µL from barcode_plate A000 to well 83.0
# Transfer 1.0 µL from barcode_plate A000 to well 85.0
# Transfer 1.0 µL from barcode_plate A000 to well 86.0
# Transfer 1.0 µL from barcode_plate A000 to well 87.0
# Transfer 1.0 µL from barcode_plate A000 to well 88.0
# Transfer 1.0 µL from barcode_plate A000 to well 89.0
# Transfer 1.0 µL from barcode_plate A000 to well 90.0
# Transfer 1.0 µL from barcode_plate A000 to well 91.0
# Transfer 1.0 µL from barcode_plate A000 to well 0.0
# Transfer 1.0 µL from barcode_plate A000 to well 1.0
# Transfer 1.0 µL from barcode_plate A000 to well 84.0
# Transfer 1.0 µL from barcode_plate A000 to well 71.0
# Transfer 1.0 µL from barcode_plate A000 to well 75.0
# Transfer 1.0 µL from barcode_plate A000 to well 69.0
# Transfer 1.0 µL from barcode_plate A000 to well 49.0
# Transfer 1.0 µL from barcode_plate A000 to well 50.0
# Transfer 1.0 µL from barcode_plate A000 to well 51.0
# Transfer 1.0 µL from barcode_plate A000 to well 52.0
# Transfer 1.0 µL from barcode_plate A000 to well 53.0
# Transfer 1.0 µL from barcode_plate A000 to well 54.0
# Transfer 1.0 µL from barcode_plate A000 to well 70.0
# Transfer 1.0 µL from barcode_plate A000 to well 56.0
# Transfer 1.0 µL from barcode_plate A000 to well 57.0
# Transfer 1.0 µL from barcode_plate A000 to well 58.0
# Transfer 1.0 µL from barcode_plate A000 to well 55.0
# Transfer 1.0 µL from barcode_plate A000 to well 60.0
# Transfer 1.0 µL from barcode_plate A000 to well 59.0
# Transfer 1.0 µL from barcode_plate A000 to well 67.0
# Transfer 1.0 µL from barcode_plate A000 to well 66.0
# Transfer 1.0 µL from barcode_plate A000 to well 65.0
# Transfer 1.0 µL from barcode_plate A000 to well 68.0
# Transfer 1.0 µL from barcode_plate A000 to well 63.0
# Transfer 1.0 µL from barcode_plate A000 to well 62.0
# Transfer 1.0 µL from barcode_plate A000 to well 61.0
# Transfer 1.0 µL from barcode_plate A000 to well 64.0
# Transfer 1.0 µL from barcode_plate A001 to well 230.0
# Transfer 1.0 µL from barcode_plate A001 to well 222.0
# Transfer 1.0 µL from barcode_plate A001 to well 223.0
# Transfer 1.0 µL from barcode_plate A001 to well 224.0
# Transfer 1.0 µL from barcode_plate A001 to well 225.0
# Transfer 1.0 µL from barcode_plate A001 to well 226.0
# Transfer 1.0 µL from barcode_plate A001 to well 227.0
# Transfer 1.0 µL from barcode_plate A001 to well 228.0
# Transfer 1.0 µL from barcode_plate A001 to well 229.0
# Transfer 1.0 µL from barcode_plate A001 to well 231.0
# Transfer 1.0 µL from barcode_plate A001 to well 197.0
# Transfer 1.0 µL from barcode_plate A001 to well 233.0
# Transfer 1.0 µL from barcode_plate A001 to well 234.0
# Transfer 1.0 µL from barcode_plate A001 to well 235.0
# Transfer 1.0 µL from barcode_plate A001 to well 236.0
# Transfer 1.0 µL from barcode_plate A001 to well 237.0
# Transfer 1.0 µL from barcode_plate A001 to well 238.0
# Transfer 1.0 µL from barcode_plate A001 to well 239.0
# Transfer 1.0 µL from barcode_plate A001 to well 240.0
# Transfer 1.0 µL from barcode_plate A001 to well 241.0
# Transfer 1.0 µL from barcode_plate A001 to well 232.0
# Transfer 1.0 µL from barcode_plate A001 to well 221.0
# Transfer 1.0 µL from barcode_plate A001 to well 198.0
# Transfer 1.0 µL from barcode_plate A001 to well 219.0
# Transfer 1.0 µL from barcode_plate A001 to well 242.0
# Transfer 1.0 µL from barcode_plate A001 to well 199.0
# Transfer 1.0 µL from barcode_plate A001 to well 200.0
# Transfer 1.0 µL from barcode_plate A001 to well 201.0
# Transfer 1.0 µL from barcode_plate A001 to well 202.0
# Transfer 1.0 µL from barcode_plate A001 to well 203.0
# Transfer 1.0 µL from barcode_plate A001 to well 204.0
# Transfer 1.0 µL from barcode_plate A001 to well 205.0
# Transfer 1.0 µL from barcode_plate A001 to well 206.0
# Transfer 1.0 µL from barcode_plate A001 to well 207.0
# Transfer 1.0 µL from barcode_plate A001 to well 208.0
# Transfer 1.0 µL from barcode_plate A001 to well 209.0
# Transfer 1.0 µL from barcode_plate A001 to well 210.0
# Transfer 1.0 µL from barcode_plate A001 to well 211.0
# Transfer 1.0 µL from barcode_plate A001 to well 212.0
# Transfer 1.0 µL from barcode_plate A001 to well 213.0
# Transfer 1.0 µL from barcode_plate A001 to well 214.0
# Transfer 1.0 µL from barcode_plate A001 to well 215.0
# Transfer 1.0 µL from barcode_plate A001 to well 216.0
# Transfer 1.0 µL from barcode_plate A001 to well 217.0
# Transfer 1.0 µL from barcode_plate A001 to well 218.0
# Transfer 1.0 µL from barcode_plate A001 to well 220.0
# Transfer 1.0 µL from barcode_plate A001 to well 244.0
# Transfer 1.0 µL from barcode_plate A001 to well 267.0
# Transfer 1.0 µL from barcode_plate A001 to well 246.0
# Transfer 1.0 µL from barcode_plate A001 to well 272.0
# Transfer 1.0 µL from barcode_plate A001 to well 273.0
# Transfer 1.0 µL from barcode_plate A001 to well 274.0
# Transfer 1.0 µL from barcode_plate A001 to well 275.0
# Transfer 1.0 µL from barcode_plate A001 to well 276.0
# Transfer 1.0 µL from barcode_plate A001 to well 277.0
# Transfer 1.0 µL from barcode_plate A001 to well 278.0
# Transfer 1.0 µL from barcode_plate A001 to well 279.0
# Transfer 1.0 µL from barcode_plate A001 to well 280.0
# Transfer 1.0 µL from barcode_plate A001 to well 271.0
# Transfer 1.0 µL from barcode_plate A001 to well 281.0
# Transfer 1.0 µL from barcode_plate A001 to well 283.0
# Transfer 1.0 µL from barcode_plate A001 to well 284.0
# Transfer 1.0 µL from barcode_plate A001 to well 285.0
# Transfer 1.0 µL from barcode_plate A001 to well 286.0
# Transfer 1.0 µL from barcode_plate A001 to well 287.0
# Transfer 1.0 µL from barcode_plate A001 to well 288.0
# Transfer 1.0 µL from barcode_plate A001 to well 289.0
# Transfer 1.0 µL from barcode_plate A001 to well 290.0
# Transfer 1.0 µL from barcode_plate A001 to well 291.0
# Transfer 1.0 µL from barcode_plate A001 to well 282.0
# Transfer 1.0 µL from barcode_plate A001 to well 245.0
# Transfer 1.0 µL from barcode_plate A001 to well 270.0
# Transfer 1.0 µL from barcode_plate A001 to well 268.0
# Transfer 1.0 µL from barcode_plate A001 to well 247.0
# Transfer 1.0 µL from barcode_plate A001 to well 248.0
# Transfer 1.0 µL from barcode_plate A001 to well 249.0
# Transfer 1.0 µL from barcode_plate A001 to well 250.0
# Transfer 1.0 µL from barcode_plate A001 to well 251.0
# Transfer 1.0 µL from barcode_plate A001 to well 252.0
# Transfer 1.0 µL from barcode_plate A001 to well 253.0
# Transfer 1.0 µL from barcode_plate A001 to well 254.0
# Transfer 1.0 µL from barcode_plate A001 to well 255.0
# Transfer 1.0 µL from barcode_plate A001 to well 269.0
# Transfer 1.0 µL from barcode_plate A001 to well 256.0
# Transfer 1.0 µL from barcode_plate A001 to well 258.0
# Transfer 1.0 µL from barcode_plate A001 to well 259.0
# Transfer 1.0 µL from barcode_plate A001 to well 260.0
# Transfer 1.0 µL from barcode_plate A001 to well 261.0
# Transfer 1.0 µL from barcode_plate A001 to well 262.0
# Transfer 1.0 µL from barcode_plate A001 to well 263.0
# Transfer 1.0 µL from barcode_plate A001 to well 264.0
# Transfer 1.0 µL from barcode_plate A001 to well 265.0
# Transfer 1.0 µL from barcode_plate A001 to well 266.0
# Transfer 1.0 µL from barcode_plate A001 to well 257.0
# Transfer 1.0 µL from barcode_plate A001 to well 196.0
# Transfer 1.0 µL from barcode_plate A001 to well 243.0
# Transfer 1.0 µL from barcode_plate A001 to well 194.0
# Transfer 1.0 µL from barcode_plate A001 to well 126.0
# Transfer 1.0 µL from barcode_plate A001 to well 127.0
# Transfer 1.0 µL from barcode_plate A001 to well 128.0
# Transfer 1.0 µL from barcode_plate A001 to well 129.0
# Transfer 1.0 µL from barcode_plate A001 to well 130.0
# Transfer 1.0 µL from barcode_plate A001 to well 131.0
# Transfer 1.0 µL from barcode_plate A001 to well 132.0
# Transfer 1.0 µL from barcode_plate A001 to well 133.0
# Transfer 1.0 µL from barcode_plate A001 to well 134.0
# Transfer 1.0 µL from barcode_plate A001 to well 125.0
# Transfer 1.0 µL from barcode_plate A001 to well 135.0
# Transfer 1.0 µL from barcode_plate A001 to well 137.0
# Transfer 1.0 µL from barcode_plate A001 to well 138.0
# Transfer 1.0 µL from barcode_plate A001 to well 139.0
# Transfer 1.0 µL from barcode_plate A001 to well 140.0
# Transfer 1.0 µL from barcode_plate A001 to well 141.0
# Transfer 1.0 µL from barcode_plate A001 to well 142.0
# Transfer 1.0 µL from barcode_plate A001 to well 143.0
# Transfer 1.0 µL from barcode_plate A001 to well 144.0
# Transfer 1.0 µL from barcode_plate A001 to well 145.0
# Transfer 1.0 µL from barcode_plate A001 to well 136.0
# Transfer 1.0 µL from barcode_plate A001 to well 124.0
# Transfer 1.0 µL from barcode_plate A001 to well 123.0
# Transfer 1.0 µL from barcode_plate A001 to well 122.0
# Transfer 1.0 µL from barcode_plate A001 to well 101.0
# Transfer 1.0 µL from barcode_plate A001 to well 102.0
# Transfer 1.0 µL from barcode_plate A001 to well 103.0
# Transfer 1.0 µL from barcode_plate A001 to well 104.0
# Transfer 1.0 µL from barcode_plate A001 to well 105.0
# Transfer 1.0 µL from barcode_plate A001 to well 106.0
# Transfer 1.0 µL from barcode_plate A001 to well 107.0
# Transfer 1.0 µL from barcode_plate A001 to well 108.0
# Transfer 1.0 µL from barcode_plate A001 to well 109.0
# Transfer 1.0 µL from barcode_plate A001 to well 110.0
# Transfer 1.0 µL from barcode_plate A001 to well 111.0
# Transfer 1.0 µL from barcode_plate A001 to well 112.0
# Transfer 1.0 µL from barcode_plate A001 to well 113.0
# Transfer 1.0 µL from barcode_plate A001 to well 114.0
# Transfer 1.0 µL from barcode_plate A001 to well 115.0
# Transfer 1.0 µL from barcode_plate A001 to well 116.0
# Transfer 1.0 µL from barcode_plate A001 to well 117.0
# Transfer 1.0 µL from barcode_plate A001 to well 118.0
# Transfer 1.0 µL from barcode_plate A001 to well 119.0
# Transfer 1.0 µL from barcode_plate A001 to well 120.0
# Transfer 1.0 µL from barcode_plate A001 to well 121.0
# Transfer 1.0 µL from barcode_plate A001 to well 146.0
# Transfer 1.0 µL from barcode_plate A001 to well 147.0
# Transfer 1.0 µL from barcode_plate A001 to well 100.0
# Transfer 1.0 µL from barcode_plate A001 to well 148.0
# Transfer 1.0 µL from barcode_plate A001 to well 174.0
# Transfer 1.0 µL from barcode_plate A001 to well 175.0
# Transfer 1.0 µL from barcode_plate A001 to well 176.0
# Transfer 1.0 µL from barcode_plate A001 to well 177.0
# Transfer 1.0 µL from barcode_plate A001 to well 178.0
# Transfer 1.0 µL from barcode_plate A001 to well 179.0
# Transfer 1.0 µL from barcode_plate A001 to well 180.0
# Transfer 1.0 µL from barcode_plate A001 to well 181.0
# Transfer 1.0 µL from barcode_plate A001 to well 182.0
# Transfer 1.0 µL from barcode_plate A001 to well 173.0
# Transfer 1.0 µL from barcode_plate A001 to well 183.0
# Transfer 1.0 µL from barcode_plate A001 to well 185.0
# Transfer 1.0 µL from barcode_plate A001 to well 186.0
# Transfer 1.0 µL from barcode_plate A001 to well 187.0
# Transfer 1.0 µL from barcode_plate A001 to well 188.0
# Transfer 1.0 µL from barcode_plate A001 to well 189.0
# Transfer 1.0 µL from barcode_plate A001 to well 190.0
# Transfer 1.0 µL from barcode_plate A001 to well 191.0
# Transfer 1.0 µL from barcode_plate A001 to well 192.0
# Transfer 1.0 µL from barcode_plate A001 to well 193.0
# Transfer 1.0 µL from barcode_plate A001 to well 184.0
# Transfer 1.0 µL from barcode_plate A001 to well 172.0
# Transfer 1.0 µL from barcode_plate A001 to well 195.0
# Transfer 1.0 µL from barcode_plate A001 to well 170.0
# Transfer 1.0 µL from barcode_plate A001 to well 171.0
# Transfer 1.0 µL from barcode_plate A001 to well 149.0
# Transfer 1.0 µL from barcode_plate A001 to well 150.0
# Transfer 1.0 µL from barcode_plate A001 to well 151.0
# Transfer 1.0 µL from barcode_plate A001 to well 152.0
# Transfer 1.0 µL from barcode_plate A001 to well 153.0
# Transfer 1.0 µL from barcode_plate A001 to well 155.0
# Transfer 1.0 µL from barcode_plate A001 to well 156.0
# Transfer 1.0 µL from barcode_plate A001 to well 157.0
# Transfer 1.0 µL from barcode_plate A001 to well 158.0
# Transfer 1.0 µL from barcode_plate A001 to well 154.0
# Transfer 1.0 µL from barcode_plate A001 to well 160.0
# Transfer 1.0 µL from barcode_plate A001 to well 161.0
# Transfer 1.0 µL from barcode_plate A001 to well 162.0
# Transfer 1.0 µL from barcode_plate A001 to well 163.0
# Transfer 1.0 µL from barcode_plate A001 to well 169.0
# Transfer 1.0 µL from barcode_plate A001 to well 164.0
# Transfer 1.0 µL from barcode_plate A001 to well 165.0
# Transfer 1.0 µL from barcode_plate A001 to well 166.0
# Transfer 1.0 µL from barcode_plate A001 to well 167.0
# Transfer 1.0 µL from barcode_plate A001 to well 168.0
# Transfer 1.0 µL from barcode_plate A001 to well 159.0
# Transfer 1.0 µL from barcode_plate A002 to well 76.0
# Transfer 1.0 µL from barcode_plate A002 to well 75.0
# Transfer 1.0 µL from barcode_plate A002 to well 74.0
# Transfer 1.0 µL from barcode_plate A002 to well 69.0
# Transfer 1.0 µL from barcode_plate A002 to well 72.0
# Transfer 1.0 µL from barcode_plate A002 to well 71.0
# Transfer 1.0 µL from barcode_plate A002 to well 70.0
# Transfer 1.0 µL from barcode_plate A002 to well 77.0
# Transfer 1.0 µL from barcode_plate A002 to well 73.0
# Transfer 1.0 µL from barcode_plate A002 to well 78.0
# Transfer 1.0 µL from barcode_plate A002 to well 88.0
# Transfer 1.0 µL from barcode_plate A002 to well 80.0
# Transfer 1.0 µL from barcode_plate A002 to well 81.0
# Transfer 1.0 µL from barcode_plate A002 to well 82.0
# Transfer 1.0 µL from barcode_plate A002 to well 83.0
# Transfer 1.0 µL from barcode_plate A002 to well 84.0
# Transfer 1.0 µL from barcode_plate A002 to well 85.0
# Transfer 1.0 µL from barcode_plate A002 to well 86.0
# Transfer 1.0 µL from barcode_plate A002 to well 87.0
# Transfer 1.0 µL from barcode_plate A002 to well 68.0
# Transfer 1.0 µL from barcode_plate A002 to well 79.0
# Transfer 1.0 µL from barcode_plate A002 to well 67.0
# Transfer 1.0 µL from barcode_plate A002 to well 56.0
# Transfer 1.0 µL from barcode_plate A002 to well 65.0
# Transfer 1.0 µL from barcode_plate A002 to well 44.0
# Transfer 1.0 µL from barcode_plate A002 to well 45.0
# Transfer 1.0 µL from barcode_plate A002 to well 46.0
# Transfer 1.0 µL from barcode_plate A002 to well 47.0
# Transfer 1.0 µL from barcode_plate A002 to well 48.0
# Transfer 1.0 µL from barcode_plate A002 to well 49.0
# Transfer 1.0 µL from barcode_plate A002 to well 50.0
# Transfer 1.0 µL from barcode_plate A002 to well 51.0
# Transfer 1.0 µL from barcode_plate A002 to well 52.0
# Transfer 1.0 µL from barcode_plate A002 to well 53.0
# Transfer 1.0 µL from barcode_plate A002 to well 54.0
# Transfer 1.0 µL from barcode_plate A002 to well 55.0
# Transfer 1.0 µL from barcode_plate A002 to well 89.0
# Transfer 1.0 µL from barcode_plate A002 to well 57.0
# Transfer 1.0 µL from barcode_plate A002 to well 58.0
# Transfer 1.0 µL from barcode_plate A002 to well 59.0
# Transfer 1.0 µL from barcode_plate A002 to well 60.0
# Transfer 1.0 µL from barcode_plate A002 to well 61.0
# Transfer 1.0 µL from barcode_plate A002 to well 62.0
# Transfer 1.0 µL from barcode_plate A002 to well 63.0
# Transfer 1.0 µL from barcode_plate A002 to well 64.0
# Transfer 1.0 µL from barcode_plate A002 to well 66.0
# Transfer 1.0 µL from barcode_plate A002 to well 90.0
# Transfer 1.0 µL from barcode_plate A002 to well 101.0
# Transfer 1.0 µL from barcode_plate A002 to well 92.0
# Transfer 1.0 µL from barcode_plate A002 to well 119.0
# Transfer 1.0 µL from barcode_plate A002 to well 120.0
# Transfer 1.0 µL from barcode_plate A002 to well 121.0
# Transfer 1.0 µL from barcode_plate A002 to well 122.0
# Transfer 1.0 µL from barcode_plate A002 to well 123.0
# Transfer 1.0 µL from barcode_plate A002 to well 124.0
# Transfer 1.0 µL from barcode_plate A002 to well 125.0
# Transfer 1.0 µL from barcode_plate A002 to well 126.0
# Transfer 1.0 µL from barcode_plate A002 to well 127.0
# Transfer 1.0 µL from barcode_plate A002 to well 118.0
# Transfer 1.0 µL from barcode_plate A002 to well 128.0
# Transfer 1.0 µL from barcode_plate A002 to well 130.0
# Transfer 1.0 µL from barcode_plate A002 to well 131.0
# Transfer 1.0 µL from barcode_plate A002 to well 132.0
# Transfer 1.0 µL from barcode_plate A002 to well 133.0
# Transfer 1.0 µL from barcode_plate A002 to well 134.0
# Transfer 1.0 µL from barcode_plate A002 to well 135.0
# Transfer 1.0 µL from barcode_plate A002 to well 136.0
# Transfer 1.0 µL from barcode_plate A002 to well 137.0
# Transfer 1.0 µL from barcode_plate A002 to well 43.0
# Transfer 1.0 µL from barcode_plate A002 to well 129.0
# Transfer 1.0 µL from barcode_plate A002 to well 117.0
# Transfer 1.0 µL from barcode_plate A002 to well 116.0
# Transfer 1.0 µL from barcode_plate A002 to well 115.0
# Transfer 1.0 µL from barcode_plate A002 to well 93.0
# Transfer 1.0 µL from barcode_plate A002 to well 94.0
# Transfer 1.0 µL from barcode_plate A002 to well 95.0
# Transfer 1.0 µL from barcode_plate A002 to well 96.0
# Transfer 1.0 µL from barcode_plate A002 to well 97.0
# Transfer 1.0 µL from barcode_plate A002 to well 98.0
# Transfer 1.0 µL from barcode_plate A002 to well 99.0
# Transfer 1.0 µL from barcode_plate A002 to well 100.0
# Transfer 1.0 µL from barcode_plate A002 to well 102.0
# Transfer 1.0 µL from barcode_plate A002 to well 103.0
# Transfer 1.0 µL from barcode_plate A002 to well 104.0
# Transfer 1.0 µL from barcode_plate A002 to well 105.0
# Transfer 1.0 µL from barcode_plate A002 to well 106.0
# Transfer 1.0 µL from barcode_plate A002 to well 107.0
# Transfer 1.0 µL from barcode_plate A002 to well 108.0
# Transfer 1.0 µL from barcode_plate A002 to well 109.0
# Transfer 1.0 µL from barcode_plate A002 to well 110.0
# Transfer 1.0 µL from barcode_plate A002 to well 111.0
# Transfer 1.0 µL from barcode_plate A002 to well 112.0
# Transfer 1.0 µL from barcode_plate A002 to well 138.0
# Transfer 1.0 µL from barcode_plate A002 to well 114.0
# Transfer 1.0 µL from barcode_plate A002 to well 91.0
# Transfer 1.0 µL from barcode_plate A002 to well 113.0
# Transfer 1.0 µL from barcode_plate A002 to well 42.0
# Transfer 1.0 µL from barcode_plate A002 to well 40.0
# Transfer 1.0 µL from barcode_plate A002 to well 316.0
# Transfer 1.0 µL from barcode_plate A002 to well 317.0
# Transfer 1.0 µL from barcode_plate A002 to well 318.0
# Transfer 1.0 µL from barcode_plate A002 to well 319.0
# Transfer 1.0 µL from barcode_plate A002 to well 320.0
# Transfer 1.0 µL from barcode_plate A002 to well 321.0
# Transfer 1.0 µL from barcode_plate A002 to well 322.0
# Transfer 1.0 µL from barcode_plate A002 to well 323.0
# Transfer 1.0 µL from barcode_plate A002 to well 324.0
# Transfer 1.0 µL from barcode_plate A002 to well 314.0
# Transfer 1.0 µL from barcode_plate A002 to well 325.0
# Transfer 1.0 µL from barcode_plate A002 to well 327.0
# Transfer 1.0 µL from barcode_plate A002 to well 328.0
# Transfer 1.0 µL from barcode_plate A002 to well 329.0
# Transfer 1.0 µL from barcode_plate A002 to well 330.0
# Transfer 1.0 µL from barcode_plate A002 to well 331.0
# Transfer 1.0 µL from barcode_plate A002 to well 332.0
# Transfer 1.0 µL from barcode_plate A002 to well 333.0
# Transfer 1.0 µL from barcode_plate A002 to well 334.0
# Transfer 1.0 µL from barcode_plate A002 to well 335.0
# Transfer 1.0 µL from barcode_plate A002 to well 326.0
# Transfer 1.0 µL from barcode_plate A002 to well 336.0
# Transfer 1.0 µL from barcode_plate A002 to well 313.0
# Transfer 1.0 µL from barcode_plate A002 to well 311.0
# Transfer 1.0 µL from barcode_plate A002 to well 41.0
# Transfer 1.0 µL from barcode_plate A002 to well 292.0
# Transfer 1.0 µL from barcode_plate A002 to well 293.0
# Transfer 1.0 µL from barcode_plate A002 to well 294.0
# Transfer 1.0 µL from barcode_plate A002 to well 295.0
# Transfer 1.0 µL from barcode_plate A002 to well 296.0
# Transfer 1.0 µL from barcode_plate A002 to well 297.0
# Transfer 1.0 µL from barcode_plate A002 to well 298.0
# Transfer 1.0 µL from barcode_plate A002 to well 299.0
# Transfer 1.0 µL from barcode_plate A002 to well 312.0
# Transfer 1.0 µL from barcode_plate A002 to well 300.0
# Transfer 1.0 µL from barcode_plate A002 to well 302.0
# Transfer 1.0 µL from barcode_plate A002 to well 303.0
# Transfer 1.0 µL from barcode_plate A002 to well 304.0
# Transfer 1.0 µL from barcode_plate A002 to well 305.0
# Transfer 1.0 µL from barcode_plate A002 to well 306.0
# Transfer 1.0 µL from barcode_plate A002 to well 307.0
# Transfer 1.0 µL from barcode_plate A002 to well 308.0
# Transfer 1.0 µL from barcode_plate A002 to well 309.0
# Transfer 1.0 µL from barcode_plate A002 to well 310.0
# Transfer 1.0 µL from barcode_plate A002 to well 301.0
# Transfer 1.0 µL from barcode_plate A002 to well 337.0
# Transfer 1.0 µL from barcode_plate A002 to well 315.0
# Transfer 1.0 µL from barcode_plate A002 to well 339.0
# Transfer 1.0 µL from barcode_plate A002 to well 19.0
# Transfer 1.0 µL from barcode_plate A002 to well 20.0
# Transfer 1.0 µL from barcode_plate A002 to well 21.0
# Transfer 1.0 µL from barcode_plate A002 to well 22.0
# Transfer 1.0 µL from barcode_plate A002 to well 23.0
# Transfer 1.0 µL from barcode_plate A002 to well 24.0
# Transfer 1.0 µL from barcode_plate A002 to well 25.0
# Transfer 1.0 µL from barcode_plate A002 to well 26.0
# Transfer 1.0 µL from barcode_plate A002 to well 28.0
# Transfer 1.0 µL from barcode_plate A002 to well 29.0
# Transfer 1.0 µL from barcode_plate A002 to well 30.0
# Transfer 1.0 µL from barcode_plate A002 to well 31.0
# Transfer 1.0 µL from barcode_plate A002 to well 32.0
# Transfer 1.0 µL from barcode_plate A002 to well 33.0
# Transfer 1.0 µL from barcode_plate A002 to well 34.0
# Transfer 1.0 µL from barcode_plate A002 to well 35.0
# Transfer 1.0 µL from barcode_plate A002 to well 36.0
# Transfer 1.0 µL from barcode_plate A002 to well 37.0
# Transfer 1.0 µL from barcode_plate A002 to well 38.0
# Transfer 1.0 µL from barcode_plate A002 to well 338.0
# Transfer 1.0 µL from barcode_plate A002 to well 39.0
# Transfer 1.0 µL from barcode_plate A002 to well 18.0
# Transfer 1.0 µL from barcode_plate A002 to well 17.0
# Transfer 1.0 µL from barcode_plate A002 to well 27.0
# Transfer 1.0 µL from barcode_plate A002 to well 341.0
# Transfer 1.0 µL from barcode_plate A002 to well 340.0
# Transfer 1.0 µL from barcode_plate A002 to well 16.0
# Transfer 1.0 µL from barcode_plate A002 to well 342.0
# Transfer 1.0 µL from barcode_plate A002 to well 343.0
# Transfer 1.0 µL from barcode_plate A002 to well 344.0
# Transfer 1.0 µL from barcode_plate A002 to well 0.0
# Transfer 1.0 µL from barcode_plate A002 to well 1.0
# Transfer 1.0 µL from barcode_plate A002 to well 3.0
# Transfer 1.0 µL from barcode_plate A002 to well 4.0
# Transfer 1.0 µL from barcode_plate A002 to well 5.0
# Transfer 1.0 µL from barcode_plate A002 to well 2.0
# Transfer 1.0 µL from barcode_plate A002 to well 7.0
# Transfer 1.0 µL from barcode_plate A002 to well 15.0
# Transfer 1.0 µL from barcode_plate A002 to well 6.0
# Transfer 1.0 µL from barcode_plate A002 to well 13.0
# Transfer 1.0 µL from barcode_plate A002 to well 12.0
# Transfer 1.0 µL from barcode_plate A002 to well 11.0
# Transfer 1.0 µL from barcode_plate A002 to well 14.0
# Transfer 1.0 µL from barcode_plate A002 to well 9.0
# Transfer 1.0 µL from barcode_plate A002 to well 8.0
# Transfer 1.0 µL from barcode_plate A002 to well 10.0
# Transfer 1.0 µL from barcode_plate A003 to well 55.0
# Transfer 1.0 µL from barcode_plate A003 to well 47.0
# Transfer 1.0 µL from barcode_plate A003 to well 48.0
# Transfer 1.0 µL from barcode_plate A003 to well 49.0
# Transfer 1.0 µL from barcode_plate A003 to well 50.0
# Transfer 1.0 µL from barcode_plate A003 to well 51.0
# Transfer 1.0 µL from barcode_plate A003 to well 52.0
# Transfer 1.0 µL from barcode_plate A003 to well 53.0
# Transfer 1.0 µL from barcode_plate A003 to well 54.0
# Transfer 1.0 µL from barcode_plate A003 to well 56.0
# Transfer 1.0 µL from barcode_plate A003 to well 66.0
# Transfer 1.0 µL from barcode_plate A003 to well 58.0
# Transfer 1.0 µL from barcode_plate A003 to well 59.0
# Transfer 1.0 µL from barcode_plate A003 to well 60.0
# Transfer 1.0 µL from barcode_plate A003 to well 61.0
# Transfer 1.0 µL from barcode_plate A003 to well 62.0
# Transfer 1.0 µL from barcode_plate A003 to well 63.0
# Transfer 1.0 µL from barcode_plate A003 to well 64.0
# Transfer 1.0 µL from barcode_plate A003 to well 65.0
# Transfer 1.0 µL from barcode_plate A003 to well 46.0
# Transfer 1.0 µL from barcode_plate A003 to well 57.0
# Transfer 1.0 µL from barcode_plate A003 to well 45.0
# Transfer 1.0 µL from barcode_plate A003 to well 22.0
# Transfer 1.0 µL from barcode_plate A003 to well 43.0
# Transfer 1.0 µL from barcode_plate A003 to well 67.0
# Transfer 1.0 µL from barcode_plate A003 to well 23.0
# Transfer 1.0 µL from barcode_plate A003 to well 24.0
# Transfer 1.0 µL from barcode_plate A003 to well 25.0
# Transfer 1.0 µL from barcode_plate A003 to well 26.0
# Transfer 1.0 µL from barcode_plate A003 to well 27.0
# Transfer 1.0 µL from barcode_plate A003 to well 28.0
# Transfer 1.0 µL from barcode_plate A003 to well 29.0
# Transfer 1.0 µL from barcode_plate A003 to well 30.0
# Transfer 1.0 µL from barcode_plate A003 to well 31.0
# Transfer 1.0 µL from barcode_plate A003 to well 32.0
# Transfer 1.0 µL from barcode_plate A003 to well 33.0
# Transfer 1.0 µL from barcode_plate A003 to well 34.0
# Transfer 1.0 µL from barcode_plate A003 to well 35.0
# Transfer 1.0 µL from barcode_plate A003 to well 36.0
# Transfer 1.0 µL from barcode_plate A003 to well 37.0
# Transfer 1.0 µL from barcode_plate A003 to well 38.0
# Transfer 1.0 µL from barcode_plate A003 to well 39.0
# Transfer 1.0 µL from barcode_plate A003 to well 40.0
# Transfer 1.0 µL from barcode_plate A003 to well 41.0
# Transfer 1.0 µL from barcode_plate A003 to well 42.0
# Transfer 1.0 µL from barcode_plate A003 to well 44.0
# Transfer 1.0 µL from barcode_plate A003 to well 68.0
# Transfer 1.0 µL from barcode_plate A003 to well 115.0
# Transfer 1.0 µL from barcode_plate A003 to well 70.0
# Transfer 1.0 µL from barcode_plate A003 to well 96.0
# Transfer 1.0 µL from barcode_plate A003 to well 97.0
# Transfer 1.0 µL from barcode_plate A003 to well 98.0
# Transfer 1.0 µL from barcode_plate A003 to well 99.0
# Transfer 1.0 µL from barcode_plate A003 to well 100.0
# Transfer 1.0 µL from barcode_plate A003 to well 101.0
# Transfer 1.0 µL from barcode_plate A003 to well 102.0
# Transfer 1.0 µL from barcode_plate A003 to well 103.0
# Transfer 1.0 µL from barcode_plate A003 to well 104.0
# Transfer 1.0 µL from barcode_plate A003 to well 95.0
# Transfer 1.0 µL from barcode_plate A003 to well 105.0
# Transfer 1.0 µL from barcode_plate A003 to well 107.0
# Transfer 1.0 µL from barcode_plate A003 to well 108.0
# Transfer 1.0 µL from barcode_plate A003 to well 109.0
# Transfer 1.0 µL from barcode_plate A003 to well 110.0
# Transfer 1.0 µL from barcode_plate A003 to well 111.0
# Transfer 1.0 µL from barcode_plate A003 to well 112.0
# Transfer 1.0 µL from barcode_plate A003 to well 113.0
# Transfer 1.0 µL from barcode_plate A003 to well 114.0
# Transfer 1.0 µL from barcode_plate A003 to well 21.0
# Transfer 1.0 µL from barcode_plate A003 to well 106.0
# Transfer 1.0 µL from barcode_plate A003 to well 94.0
# Transfer 1.0 µL from barcode_plate A003 to well 93.0
# Transfer 1.0 µL from barcode_plate A003 to well 92.0
# Transfer 1.0 µL from barcode_plate A003 to well 71.0
# Transfer 1.0 µL from barcode_plate A003 to well 72.0
# Transfer 1.0 µL from barcode_plate A003 to well 73.0
# Transfer 1.0 µL from barcode_plate A003 to well 74.0
# Transfer 1.0 µL from barcode_plate A003 to well 75.0
# Transfer 1.0 µL from barcode_plate A003 to well 76.0
# Transfer 1.0 µL from barcode_plate A003 to well 77.0
# Transfer 1.0 µL from barcode_plate A003 to well 78.0
# Transfer 1.0 µL from barcode_plate A003 to well 79.0
# Transfer 1.0 µL from barcode_plate A003 to well 80.0
# Transfer 1.0 µL from barcode_plate A003 to well 81.0
# Transfer 1.0 µL from barcode_plate A003 to well 82.0
# Transfer 1.0 µL from barcode_plate A003 to well 83.0
# Transfer 1.0 µL from barcode_plate A003 to well 84.0
# Transfer 1.0 µL from barcode_plate A003 to well 85.0
# Transfer 1.0 µL from barcode_plate A003 to well 86.0
# Transfer 1.0 µL from barcode_plate A003 to well 87.0
# Transfer 1.0 µL from barcode_plate A003 to well 88.0
# Transfer 1.0 µL from barcode_plate A003 to well 89.0
# Transfer 1.0 µL from barcode_plate A003 to well 90.0
# Transfer 1.0 µL from barcode_plate A003 to well 91.0
# Transfer 1.0 µL from barcode_plate A003 to well 69.0
# Transfer 1.0 µL from barcode_plate A003 to well 20.0
# Transfer 1.0 µL from barcode_plate A003 to well 186.0
# Transfer 1.0 µL from barcode_plate A003 to well 18.0
# Transfer 1.0 µL from barcode_plate A003 to well 164.0
# Transfer 1.0 µL from barcode_plate A003 to well 165.0
# Transfer 1.0 µL from barcode_plate A003 to well 166.0
# Transfer 1.0 µL from barcode_plate A003 to well 167.0
# Transfer 1.0 µL from barcode_plate A003 to well 168.0
# Transfer 1.0 µL from barcode_plate A003 to well 169.0
# Transfer 1.0 µL from barcode_plate A003 to well 170.0
# Transfer 1.0 µL from barcode_plate A003 to well 171.0
# Transfer 1.0 µL from barcode_plate A003 to well 172.0
# Transfer 1.0 µL from barcode_plate A003 to well 163.0
# Transfer 1.0 µL from barcode_plate A003 to well 173.0
# Transfer 1.0 µL from barcode_plate A003 to well 175.0
# Transfer 1.0 µL from barcode_plate A003 to well 176.0
# Transfer 1.0 µL from barcode_plate A003 to well 177.0
# Transfer 1.0 µL from barcode_plate A003 to well 178.0
# Transfer 1.0 µL from barcode_plate A003 to well 179.0
# Transfer 1.0 µL from barcode_plate A003 to well 180.0
# Transfer 1.0 µL from barcode_plate A003 to well 181.0
# Transfer 1.0 µL from barcode_plate A003 to well 182.0
# Transfer 1.0 µL from barcode_plate A003 to well 183.0
# Transfer 1.0 µL from barcode_plate A003 to well 174.0
# Transfer 1.0 µL from barcode_plate A003 to well 184.0
# Transfer 1.0 µL from barcode_plate A003 to well 162.0
# Transfer 1.0 µL from barcode_plate A003 to well 160.0
# Transfer 1.0 µL from barcode_plate A003 to well 140.0
# Transfer 1.0 µL from barcode_plate A003 to well 141.0
# Transfer 1.0 µL from barcode_plate A003 to well 142.0
# Transfer 1.0 µL from barcode_plate A003 to well 143.0
# Transfer 1.0 µL from barcode_plate A003 to well 144.0
# Transfer 1.0 µL from barcode_plate A003 to well 145.0
# Transfer 1.0 µL from barcode_plate A003 to well 146.0
# Transfer 1.0 µL from barcode_plate A003 to well 147.0
# Transfer 1.0 µL from barcode_plate A003 to well 148.0
# Transfer 1.0 µL from barcode_plate A003 to well 161.0
# Transfer 1.0 µL from barcode_plate A003 to well 149.0
# Transfer 1.0 µL from barcode_plate A003 to well 151.0
# Transfer 1.0 µL from barcode_plate A003 to well 152.0
# Transfer 1.0 µL from barcode_plate A003 to well 153.0
# Transfer 1.0 µL from barcode_plate A003 to well 154.0
# Transfer 1.0 µL from barcode_plate A003 to well 155.0
# Transfer 1.0 µL from barcode_plate A003 to well 156.0
# Transfer 1.0 µL from barcode_plate A003 to well 157.0
# Transfer 1.0 µL from barcode_plate A003 to well 158.0
# Transfer 1.0 µL from barcode_plate A003 to well 159.0
# Transfer 1.0 µL from barcode_plate A003 to well 150.0
# Transfer 1.0 µL from barcode_plate A003 to well 185.0
# Transfer 1.0 µL from barcode_plate A003 to well 139.0
# Transfer 1.0 µL from barcode_plate A003 to well 187.0
# Transfer 1.0 µL from barcode_plate A003 to well 213.0
# Transfer 1.0 µL from barcode_plate A003 to well 214.0
# Transfer 1.0 µL from barcode_plate A003 to well 0.0
# Transfer 1.0 µL from barcode_plate A003 to well 1.0
# Transfer 1.0 µL from barcode_plate A003 to well 2.0
# Transfer 1.0 µL from barcode_plate A003 to well 3.0
# Transfer 1.0 µL from barcode_plate A003 to well 4.0
# Transfer 1.0 µL from barcode_plate A003 to well 19.0
# Transfer 1.0 µL from barcode_plate A003 to well 6.0
# Transfer 1.0 µL from barcode_plate A003 to well 212.0
# Transfer 1.0 µL from barcode_plate A003 to well 7.0
# Transfer 1.0 µL from barcode_plate A003 to well 9.0
# Transfer 1.0 µL from barcode_plate A003 to well 10.0
# Transfer 1.0 µL from barcode_plate A003 to well 11.0
# Transfer 1.0 µL from barcode_plate A003 to well 12.0
# Transfer 1.0 µL from barcode_plate A003 to well 13.0
# Transfer 1.0 µL from barcode_plate A003 to well 14.0
# Transfer 1.0 µL from barcode_plate A003 to well 15.0
# Transfer 1.0 µL from barcode_plate A003 to well 16.0
# Transfer 1.0 µL from barcode_plate A003 to well 17.0
# Transfer 1.0 µL from barcode_plate A003 to well 8.0
# Transfer 1.0 µL from barcode_plate A003 to well 211.0
# Transfer 1.0 µL from barcode_plate A003 to well 5.0
# Transfer 1.0 µL from barcode_plate A003 to well 209.0
# Transfer 1.0 µL from barcode_plate A003 to well 210.0
# Transfer 1.0 µL from barcode_plate A003 to well 189.0
# Transfer 1.0 µL from barcode_plate A003 to well 190.0
# Transfer 1.0 µL from barcode_plate A003 to well 191.0
# Transfer 1.0 µL from barcode_plate A003 to well 192.0
# Transfer 1.0 µL from barcode_plate A003 to well 193.0
# Transfer 1.0 µL from barcode_plate A003 to well 194.0
# Transfer 1.0 µL from barcode_plate A003 to well 195.0
# Transfer 1.0 µL from barcode_plate A003 to well 196.0
# Transfer 1.0 µL from barcode_plate A003 to well 197.0
# Transfer 1.0 µL from barcode_plate A003 to well 188.0
# Transfer 1.0 µL from barcode_plate A003 to well 199.0
# Transfer 1.0 µL from barcode_plate A003 to well 198.0
# Transfer 1.0 µL from barcode_plate A003 to well 207.0
# Transfer 1.0 µL from barcode_plate A003 to well 206.0
# Transfer 1.0 µL from barcode_plate A003 to well 205.0
# Transfer 1.0 µL from barcode_plate A003 to well 208.0
# Transfer 1.0 µL from barcode_plate A003 to well 203.0
# Transfer 1.0 µL from barcode_plate A003 to well 202.0
# Transfer 1.0 µL from barcode_plate A003 to well 201.0
# Transfer 1.0 µL from barcode_plate A003 to well 200.0
# Transfer 1.0 µL from barcode_plate A003 to well 204.0
# Transfer 1.0 µL from barcode_plate A004 to well 245.0
# Transfer 1.0 µL from barcode_plate A004 to well 238.0
# Transfer 1.0 µL from barcode_plate A004 to well 239.0
# Transfer 1.0 µL from barcode_plate A004 to well 240.0
# Transfer 1.0 µL from barcode_plate A004 to well 241.0
# Transfer 1.0 µL from barcode_plate A004 to well 242.0
# Transfer 1.0 µL from barcode_plate A004 to well 243.0
# Transfer 1.0 µL from barcode_plate A004 to well 244.0
# Transfer 1.0 µL from barcode_plate A004 to well 246.0
# Transfer 1.0 µL from barcode_plate A004 to well 252.0
# Transfer 1.0 µL from barcode_plate A004 to well 248.0
# Transfer 1.0 µL from barcode_plate A004 to well 249.0
# Transfer 1.0 µL from barcode_plate A004 to well 250.0
# Transfer 1.0 µL from barcode_plate A004 to well 251.0
# Transfer 1.0 µL from barcode_plate A004 to well 253.0
# Transfer 1.0 µL from barcode_plate A004 to well 254.0
# Transfer 1.0 µL from barcode_plate A004 to well 255.0
# Transfer 1.0 µL from barcode_plate A004 to well 256.0
# Transfer 1.0 µL from barcode_plate A004 to well 257.0
# Transfer 1.0 µL from barcode_plate A004 to well 247.0
# Transfer 1.0 µL from barcode_plate A004 to well 237.0
# Transfer 1.0 µL from barcode_plate A004 to well 214.0
# Transfer 1.0 µL from barcode_plate A004 to well 235.0
# Transfer 1.0 µL from barcode_plate A004 to well 258.0
# Transfer 1.0 µL from barcode_plate A004 to well 215.0
# Transfer 1.0 µL from barcode_plate A004 to well 216.0
# Transfer 1.0 µL from barcode_plate A004 to well 217.0
# Transfer 1.0 µL from barcode_plate A004 to well 218.0
# Transfer 1.0 µL from barcode_plate A004 to well 219.0
# Transfer 1.0 µL from barcode_plate A004 to well 220.0
# Transfer 1.0 µL from barcode_plate A004 to well 221.0
# Transfer 1.0 µL from barcode_plate A004 to well 222.0
# Transfer 1.0 µL from barcode_plate A004 to well 223.0
# Transfer 1.0 µL from barcode_plate A004 to well 224.0
# Transfer 1.0 µL from barcode_plate A004 to well 225.0
# Transfer 1.0 µL from barcode_plate A004 to well 226.0
# Transfer 1.0 µL from barcode_plate A004 to well 227.0
# Transfer 1.0 µL from barcode_plate A004 to well 228.0
# Transfer 1.0 µL from barcode_plate A004 to well 229.0
# Transfer 1.0 µL from barcode_plate A004 to well 230.0
# Transfer 1.0 µL from barcode_plate A004 to well 231.0
# Transfer 1.0 µL from barcode_plate A004 to well 232.0
# Transfer 1.0 µL from barcode_plate A004 to well 233.0
# Transfer 1.0 µL from barcode_plate A004 to well 234.0
# Transfer 1.0 µL from barcode_plate A004 to well 236.0
# Transfer 1.0 µL from barcode_plate A004 to well 259.0
# Transfer 1.0 µL from barcode_plate A004 to well 283.0
# Transfer 1.0 µL from barcode_plate A004 to well 261.0
# Transfer 1.0 µL from barcode_plate A004 to well 288.0
# Transfer 1.0 µL from barcode_plate A004 to well 289.0
# Transfer 1.0 µL from barcode_plate A004 to well 290.0
# Transfer 1.0 µL from barcode_plate A004 to well 291.0
# Transfer 1.0 µL from barcode_plate A004 to well 292.0
# Transfer 1.0 µL from barcode_plate A004 to well 293.0
# Transfer 1.0 µL from barcode_plate A004 to well 294.0
# Transfer 1.0 µL from barcode_plate A004 to well 295.0
# Transfer 1.0 µL from barcode_plate A004 to well 296.0
# Transfer 1.0 µL from barcode_plate A004 to well 287.0
# Transfer 1.0 µL from barcode_plate A004 to well 297.0
# Transfer 1.0 µL from barcode_plate A004 to well 299.0
# Transfer 1.0 µL from barcode_plate A004 to well 300.0
# Transfer 1.0 µL from barcode_plate A004 to well 301.0
# Transfer 1.0 µL from barcode_plate A004 to well 302.0
# Transfer 1.0 µL from barcode_plate A004 to well 303.0
# Transfer 1.0 µL from barcode_plate A004 to well 304.0
# Transfer 1.0 µL from barcode_plate A004 to well 305.0
# Transfer 1.0 µL from barcode_plate A004 to well 306.0
# Transfer 1.0 µL from barcode_plate A004 to well 213.0
# Transfer 1.0 µL from barcode_plate A004 to well 298.0
# Transfer 1.0 µL from barcode_plate A004 to well 286.0
# Transfer 1.0 µL from barcode_plate A004 to well 285.0
# Transfer 1.0 µL from barcode_plate A004 to well 284.0
# Transfer 1.0 µL from barcode_plate A004 to well 262.0
# Transfer 1.0 µL from barcode_plate A004 to well 263.0
# Transfer 1.0 µL from barcode_plate A004 to well 264.0
# Transfer 1.0 µL from barcode_plate A004 to well 265.0
# Transfer 1.0 µL from barcode_plate A004 to well 266.0
# Transfer 1.0 µL from barcode_plate A004 to well 267.0
# Transfer 1.0 µL from barcode_plate A004 to well 268.0
# Transfer 1.0 µL from barcode_plate A004 to well 269.0
# Transfer 1.0 µL from barcode_plate A004 to well 270.0
# Transfer 1.0 µL from barcode_plate A004 to well 271.0
# Transfer 1.0 µL from barcode_plate A004 to well 272.0
# Transfer 1.0 µL from barcode_plate A004 to well 273.0
# Transfer 1.0 µL from barcode_plate A004 to well 274.0
# Transfer 1.0 µL from barcode_plate A004 to well 275.0
# Transfer 1.0 µL from barcode_plate A004 to well 276.0
# Transfer 1.0 µL from barcode_plate A004 to well 277.0
# Transfer 1.0 µL from barcode_plate A004 to well 278.0
# Transfer 1.0 µL from barcode_plate A004 to well 279.0
# Transfer 1.0 µL from barcode_plate A004 to well 280.0
# Transfer 1.0 µL from barcode_plate A004 to well 281.0
# Transfer 1.0 µL from barcode_plate A004 to well 282.0
# Transfer 1.0 µL from barcode_plate A004 to well 260.0
# Transfer 1.0 µL from barcode_plate A004 to well 212.0
# Transfer 1.0 µL from barcode_plate A004 to well 307.0
# Transfer 1.0 µL from barcode_plate A004 to well 210.0
# Transfer 1.0 µL from barcode_plate A004 to well 141.0
# Transfer 1.0 µL from barcode_plate A004 to well 142.0
# Transfer 1.0 µL from barcode_plate A004 to well 143.0
# Transfer 1.0 µL from barcode_plate A004 to well 144.0
# Transfer 1.0 µL from barcode_plate A004 to well 145.0
# Transfer 1.0 µL from barcode_plate A004 to well 146.0
# Transfer 1.0 µL from barcode_plate A004 to well 147.0
# Transfer 1.0 µL from barcode_plate A004 to well 148.0
# Transfer 1.0 µL from barcode_plate A004 to well 149.0
# Transfer 1.0 µL from barcode_plate A004 to well 140.0
# Transfer 1.0 µL from barcode_plate A004 to well 150.0
# Transfer 1.0 µL from barcode_plate A004 to well 152.0
# Transfer 1.0 µL from barcode_plate A004 to well 153.0
# Transfer 1.0 µL from barcode_plate A004 to well 154.0
# Transfer 1.0 µL from barcode_plate A004 to well 155.0
# Transfer 1.0 µL from barcode_plate A004 to well 156.0
# Transfer 1.0 µL from barcode_plate A004 to well 157.0
# Transfer 1.0 µL from barcode_plate A004 to well 158.0
# Transfer 1.0 µL from barcode_plate A004 to well 159.0
# Transfer 1.0 µL from barcode_plate A004 to well 160.0
# Transfer 1.0 µL from barcode_plate A004 to well 151.0
# Transfer 1.0 µL from barcode_plate A004 to well 139.0
# Transfer 1.0 µL from barcode_plate A004 to well 138.0
# Transfer 1.0 µL from barcode_plate A004 to well 137.0
# Transfer 1.0 µL from barcode_plate A004 to well 116.0
# Transfer 1.0 µL from barcode_plate A004 to well 117.0
# Transfer 1.0 µL from barcode_plate A004 to well 118.0
# Transfer 1.0 µL from barcode_plate A004 to well 119.0
# Transfer 1.0 µL from barcode_plate A004 to well 120.0
# Transfer 1.0 µL from barcode_plate A004 to well 121.0
# Transfer 1.0 µL from barcode_plate A004 to well 122.0
# ...
# Transfer 1.0 µL from barcode_plate A026 to well 93.0
# Transfer 1.0 µL from barcode_plate A026 to well 94.0
# Transfer 1.0 µL from barcode_plate A026 to well 85.0
# Transfer 1.0 µL from barcode_plate A026 to well 73.0
# Transfer 1.0 µL from barcode_plate A026 to well 72.0
# Transfer 1.0 µL from barcode_plate A026 to well 71.0
# Transfer 1.0 µL from barcode_plate A026 to well 51.0
# Transfer 1.0 µL from barcode_plate A026 to well 52.0
# Transfer 1.0 µL from barcode_plate A026 to well 53.0
# Transfer 1.0 µL from barcode_plate A026 to well 54.0
# Transfer 1.0 µL from barcode_plate A026 to well 55.0
# Transfer 1.0 µL from barcode_plate A026 to well 56.0
# Transfer 1.0 µL from barcode_plate A026 to well 57.0
# Transfer 1.0 µL from barcode_plate A026 to well 95.0
# Transfer 1.0 µL from barcode_plate A026 to well 58.0
# Transfer 1.0 µL from barcode_plate A026 to well 59.0
# Transfer 1.0 µL from barcode_plate A026 to well 60.0
# Transfer 1.0 µL from barcode_plate A026 to well 61.0
# Transfer 1.0 µL from barcode_plate A026 to well 62.0
# Transfer 1.0 µL from barcode_plate A026 to well 63.0
# Transfer 1.0 µL from barcode_plate A026 to well 64.0
# Transfer 1.0 µL from barcode_plate A026 to well 65.0
# Transfer 1.0 µL from barcode_plate A026 to well 66.0
# Transfer 1.0 µL from barcode_plate A026 to well 67.0
# Transfer 1.0 µL from barcode_plate A026 to well 68.0
# Transfer 1.0 µL from barcode_plate A026 to well 69.0
# Transfer 1.0 µL from barcode_plate A026 to well 70.0
# Transfer 1.0 µL from barcode_plate A026 to well 49.0
# Transfer 1.0 µL from barcode_plate A026 to well 0.0
# Transfer 1.0 µL from barcode_plate A026 to well 254.0
# Transfer 1.0 µL from barcode_plate A026 to well 311.0
# Transfer 1.0 µL from barcode_plate A026 to well 241.0
# Transfer 1.0 µL from barcode_plate A026 to well 242.0
# Transfer 1.0 µL from barcode_plate A026 to well 243.0
# Transfer 1.0 µL from barcode_plate A026 to well 244.0
# Transfer 1.0 µL from barcode_plate A026 to well 245.0
# Transfer 1.0 µL from barcode_plate A026 to well 246.0
# Transfer 1.0 µL from barcode_plate A026 to well 247.0
# Transfer 1.0 µL from barcode_plate A026 to well 248.0
# Transfer 1.0 µL from barcode_plate A026 to well 249.0
# Transfer 1.0 µL from barcode_plate A026 to well 240.0
# Transfer 1.0 µL from barcode_plate A026 to well 250.0
# Transfer 1.0 µL from barcode_plate A026 to well 252.0
# Transfer 1.0 µL from barcode_plate A026 to well 253.0
# Transfer 1.0 µL from barcode_plate A026 to well 255.0
# Transfer 1.0 µL from barcode_plate A026 to well 256.0
# Transfer 1.0 µL from barcode_plate A026 to well 257.0
# Transfer 1.0 µL from barcode_plate A026 to well 258.0
# Transfer 1.0 µL from barcode_plate A026 to well 259.0
# Transfer 1.0 µL from barcode_plate A026 to well 260.0
# Transfer 1.0 µL from barcode_plate A026 to well 261.0
# Transfer 1.0 µL from barcode_plate A026 to well 251.0
# Transfer 1.0 µL from barcode_plate A026 to well 262.0
# Transfer 1.0 µL from barcode_plate A026 to well 239.0
# Transfer 1.0 µL from barcode_plate A026 to well 237.0
# Transfer 1.0 µL from barcode_plate A026 to well 312.0
# Transfer 1.0 µL from barcode_plate A026 to well 217.0
# Transfer 1.0 µL from barcode_plate A026 to well 218.0
# Transfer 1.0 µL from barcode_plate A026 to well 219.0
# Transfer 1.0 µL from barcode_plate A026 to well 220.0
# Transfer 1.0 µL from barcode_plate A026 to well 222.0
# Transfer 1.0 µL from barcode_plate A026 to well 223.0
# Transfer 1.0 µL from barcode_plate A026 to well 224.0
# Transfer 1.0 µL from barcode_plate A026 to well 225.0
# Transfer 1.0 µL from barcode_plate A026 to well 238.0
# Transfer 1.0 µL from barcode_plate A026 to well 226.0
# Transfer 1.0 µL from barcode_plate A026 to well 228.0
# Transfer 1.0 µL from barcode_plate A026 to well 229.0
# Transfer 1.0 µL from barcode_plate A026 to well 230.0
# Transfer 1.0 µL from barcode_plate A026 to well 231.0
# Transfer 1.0 µL from barcode_plate A026 to well 232.0
# Transfer 1.0 µL from barcode_plate A026 to well 233.0
# Transfer 1.0 µL from barcode_plate A026 to well 234.0
# Transfer 1.0 µL from barcode_plate A026 to well 235.0
# Transfer 1.0 µL from barcode_plate A026 to well 236.0
# Transfer 1.0 µL from barcode_plate A026 to well 227.0
# Transfer 1.0 µL from barcode_plate A026 to well 263.0
# Transfer 1.0 µL from barcode_plate A026 to well 221.0
# Transfer 1.0 µL from barcode_plate A026 to well 265.0
# Transfer 1.0 µL from barcode_plate A026 to well 291.0
# Transfer 1.0 µL from barcode_plate A026 to well 292.0
# Transfer 1.0 µL from barcode_plate A026 to well 293.0
# Transfer 1.0 µL from barcode_plate A026 to well 294.0
# Transfer 1.0 µL from barcode_plate A026 to well 295.0
# Transfer 1.0 µL from barcode_plate A026 to well 296.0
# Transfer 1.0 µL from barcode_plate A026 to well 297.0
# Transfer 1.0 µL from barcode_plate A026 to well 298.0
# Transfer 1.0 µL from barcode_plate A026 to well 299.0
# Transfer 1.0 µL from barcode_plate A026 to well 290.0
# Transfer 1.0 µL from barcode_plate A026 to well 300.0
# Transfer 1.0 µL from barcode_plate A026 to well 302.0
# Transfer 1.0 µL from barcode_plate A026 to well 303.0
# Transfer 1.0 µL from barcode_plate A026 to well 304.0
# Transfer 1.0 µL from barcode_plate A026 to well 305.0
# Transfer 1.0 µL from barcode_plate A026 to well 306.0
# Transfer 1.0 µL from barcode_plate A026 to well 308.0
# Transfer 1.0 µL from barcode_plate A026 to well 309.0
# Transfer 1.0 µL from barcode_plate A026 to well 264.0
# Transfer 1.0 µL from barcode_plate A026 to well 310.0
# Transfer 1.0 µL from barcode_plate A026 to well 301.0
# Transfer 1.0 µL from barcode_plate A026 to well 289.0
# Transfer 1.0 µL from barcode_plate A026 to well 307.0
# Transfer 1.0 µL from barcode_plate A026 to well 287.0
# Transfer 1.0 µL from barcode_plate A026 to well 288.0
# Transfer 1.0 µL from barcode_plate A026 to well 268.0
# Transfer 1.0 µL from barcode_plate A026 to well 266.0
# Transfer 1.0 µL from barcode_plate A026 to well 270.0
# Transfer 1.0 µL from barcode_plate A026 to well 271.0
# Transfer 1.0 µL from barcode_plate A026 to well 272.0
# Transfer 1.0 µL from barcode_plate A026 to well 273.0
# Transfer 1.0 µL from barcode_plate A026 to well 274.0
# Transfer 1.0 µL from barcode_plate A026 to well 275.0
# Transfer 1.0 µL from barcode_plate A026 to well 276.0
# Transfer 1.0 µL from barcode_plate A026 to well 269.0
# Transfer 1.0 µL from barcode_plate A026 to well 278.0
# Transfer 1.0 µL from barcode_plate A026 to well 286.0
# Transfer 1.0 µL from barcode_plate A026 to well 277.0
# Transfer 1.0 µL from barcode_plate A026 to well 285.0
# Transfer 1.0 µL from barcode_plate A026 to well 284.0
# Transfer 1.0 µL from barcode_plate A026 to well 283.0
# Transfer 1.0 µL from barcode_plate A026 to well 267.0
# Transfer 1.0 µL from barcode_plate A026 to well 282.0
# Transfer 1.0 µL from barcode_plate A026 to well 281.0
# Transfer 1.0 µL from barcode_plate A026 to well 280.0
# Transfer 1.0 µL from barcode_plate A026 to well 279.0
# Transfer 1.0 µL from barcode_plate A027 to well 204.0
# Transfer 1.0 µL from barcode_plate A027 to well 205.0
# Transfer 1.0 µL from barcode_plate A027 to well 206.0
# Transfer 1.0 µL from barcode_plate A027 to well 207.0
# Transfer 1.0 µL from barcode_plate A027 to well 208.0
# Transfer 1.0 µL from barcode_plate A027 to well 209.0
# Transfer 1.0 µL from barcode_plate A027 to well 210.0
# Transfer 1.0 µL from barcode_plate A027 to well 211.0
# Transfer 1.0 µL from barcode_plate A027 to well 212.0
# Transfer 1.0 µL from barcode_plate A027 to well 213.0
# Transfer 1.0 µL from barcode_plate A027 to well 214.0
# Transfer 1.0 µL from barcode_plate A027 to well 215.0
# Transfer 1.0 µL from barcode_plate A027 to well 217.0
# Transfer 1.0 µL from barcode_plate A027 to well 218.0
# Transfer 1.0 µL from barcode_plate A027 to well 219.0
# Transfer 1.0 µL from barcode_plate A027 to well 220.0
# Transfer 1.0 µL from barcode_plate A027 to well 203.0
# Transfer 1.0 µL from barcode_plate A027 to well 221.0
# Transfer 1.0 µL from barcode_plate A027 to well 216.0
# Transfer 1.0 µL from barcode_plate A027 to well 193.0
# Transfer 1.0 µL from barcode_plate A027 to well 201.0
# Transfer 1.0 µL from barcode_plate A027 to well 183.0
# Transfer 1.0 µL from barcode_plate A027 to well 222.0
# Transfer 1.0 µL from barcode_plate A027 to well 184.0
# Transfer 1.0 µL from barcode_plate A027 to well 185.0
# Transfer 1.0 µL from barcode_plate A027 to well 186.0
# Transfer 1.0 µL from barcode_plate A027 to well 187.0
# Transfer 1.0 µL from barcode_plate A027 to well 188.0
# Transfer 1.0 µL from barcode_plate A027 to well 189.0
# Transfer 1.0 µL from barcode_plate A027 to well 202.0
# Transfer 1.0 µL from barcode_plate A027 to well 190.0
# Transfer 1.0 µL from barcode_plate A027 to well 192.0
# Transfer 1.0 µL from barcode_plate A027 to well 194.0
# Transfer 1.0 µL from barcode_plate A027 to well 195.0
# Transfer 1.0 µL from barcode_plate A027 to well 196.0
# Transfer 1.0 µL from barcode_plate A027 to well 197.0
# Transfer 1.0 µL from barcode_plate A027 to well 198.0
# Transfer 1.0 µL from barcode_plate A027 to well 199.0
# Transfer 1.0 µL from barcode_plate A027 to well 200.0
# Transfer 1.0 µL from barcode_plate A027 to well 191.0
# Transfer 1.0 µL from barcode_plate A027 to well 223.0
# Transfer 1.0 µL from barcode_plate A027 to well 245.0
# Transfer 1.0 µL from barcode_plate A027 to well 225.0
# Transfer 1.0 µL from barcode_plate A027 to well 249.0
# Transfer 1.0 µL from barcode_plate A027 to well 250.0
# Transfer 1.0 µL from barcode_plate A027 to well 251.0
# Transfer 1.0 µL from barcode_plate A027 to well 252.0
# Transfer 1.0 µL from barcode_plate A027 to well 253.0
# Transfer 1.0 µL from barcode_plate A027 to well 254.0
# Transfer 1.0 µL from barcode_plate A027 to well 255.0
# Transfer 1.0 µL from barcode_plate A027 to well 256.0
# Transfer 1.0 µL from barcode_plate A027 to well 257.0
# Transfer 1.0 µL from barcode_plate A027 to well 258.0
# Transfer 1.0 µL from barcode_plate A027 to well 259.0
# Transfer 1.0 µL from barcode_plate A027 to well 260.0
# Transfer 1.0 µL from barcode_plate A027 to well 261.0
# Transfer 1.0 µL from barcode_plate A027 to well 262.0
# Transfer 1.0 µL from barcode_plate A027 to well 263.0
# Transfer 1.0 µL from barcode_plate A027 to well 264.0
# Transfer 1.0 µL from barcode_plate A027 to well 182.0
# Transfer 1.0 µL from barcode_plate A027 to well 248.0
# Transfer 1.0 µL from barcode_plate A027 to well 247.0
# Transfer 1.0 µL from barcode_plate A027 to well 246.0
# Transfer 1.0 µL from barcode_plate A027 to well 244.0
# Transfer 1.0 µL from barcode_plate A027 to well 226.0
# Transfer 1.0 µL from barcode_plate A027 to well 227.0
# Transfer 1.0 µL from barcode_plate A027 to well 228.0
# Transfer 1.0 µL from barcode_plate A027 to well 229.0
# Transfer 1.0 µL from barcode_plate A027 to well 230.0
# Transfer 1.0 µL from barcode_plate A027 to well 231.0
# Transfer 1.0 µL from barcode_plate A027 to well 232.0
# Transfer 1.0 µL from barcode_plate A027 to well 233.0
# Transfer 1.0 µL from barcode_plate A027 to well 224.0
# Transfer 1.0 µL from barcode_plate A027 to well 234.0
# Transfer 1.0 µL from barcode_plate A027 to well 236.0
# Transfer 1.0 µL from barcode_plate A027 to well 237.0
# Transfer 1.0 µL from barcode_plate A027 to well 238.0
# Transfer 1.0 µL from barcode_plate A027 to well 239.0
# Transfer 1.0 µL from barcode_plate A027 to well 240.0
# Transfer 1.0 µL from barcode_plate A027 to well 241.0
# Transfer 1.0 µL from barcode_plate A027 to well 242.0
# Transfer 1.0 µL from barcode_plate A027 to well 243.0
# Transfer 1.0 µL from barcode_plate A027 to well 235.0
# Transfer 1.0 µL from barcode_plate A027 to well 181.0
# Transfer 1.0 µL from barcode_plate A027 to well 133.0
# Transfer 1.0 µL from barcode_plate A027 to well 179.0
# Transfer 1.0 µL from barcode_plate A027 to well 117.0
# Transfer 1.0 µL from barcode_plate A027 to well 118.0
# Transfer 1.0 µL from barcode_plate A027 to well 119.0
# Transfer 1.0 µL from barcode_plate A027 to well 120.0
# Transfer 1.0 µL from barcode_plate A027 to well 121.0
# Transfer 1.0 µL from barcode_plate A027 to well 122.0
# Transfer 1.0 µL from barcode_plate A027 to well 123.0
# Transfer 1.0 µL from barcode_plate A027 to well 124.0
# Transfer 1.0 µL from barcode_plate A027 to well 125.0
# Transfer 1.0 µL from barcode_plate A027 to well 126.0
# Transfer 1.0 µL from barcode_plate A027 to well 127.0
# Transfer 1.0 µL from barcode_plate A027 to well 128.0
# Transfer 1.0 µL from barcode_plate A027 to well 129.0
# Transfer 1.0 µL from barcode_plate A027 to well 130.0
# Transfer 1.0 µL from barcode_plate A027 to well 131.0
# Transfer 1.0 µL from barcode_plate A027 to well 132.0
# Transfer 1.0 µL from barcode_plate A027 to well 134.0
# Transfer 1.0 µL from barcode_plate A027 to well 116.0
# Transfer 1.0 µL from barcode_plate A027 to well 115.0
# Transfer 1.0 µL from barcode_plate A027 to well 114.0
# Transfer 1.0 µL from barcode_plate A027 to well 113.0
# Transfer 1.0 µL from barcode_plate A027 to well 265.0
# Transfer 1.0 µL from barcode_plate A027 to well 96.0
# Transfer 1.0 µL from barcode_plate A027 to well 97.0
# Transfer 1.0 µL from barcode_plate A027 to well 98.0
# Transfer 1.0 µL from barcode_plate A027 to well 99.0
# Transfer 1.0 µL from barcode_plate A027 to well 100.0
# Transfer 1.0 µL from barcode_plate A027 to well 101.0
# Transfer 1.0 µL from barcode_plate A027 to well 102.0
# Transfer 1.0 µL from barcode_plate A027 to well 135.0
# Transfer 1.0 µL from barcode_plate A027 to well 103.0
# Transfer 1.0 µL from barcode_plate A027 to well 105.0
# Transfer 1.0 µL from barcode_plate A027 to well 106.0
# Transfer 1.0 µL from barcode_plate A027 to well 107.0
# Transfer 1.0 µL from barcode_plate A027 to well 108.0
# Transfer 1.0 µL from barcode_plate A027 to well 109.0
# Transfer 1.0 µL from barcode_plate A027 to well 110.0
# Transfer 1.0 µL from barcode_plate A027 to well 111.0
# Transfer 1.0 µL from barcode_plate A027 to well 112.0
# Transfer 1.0 µL from barcode_plate A027 to well 104.0
# Transfer 1.0 µL from barcode_plate A027 to well 136.0
# Transfer 1.0 µL from barcode_plate A027 to well 137.0
# Transfer 1.0 µL from barcode_plate A027 to well 138.0
# Transfer 1.0 µL from barcode_plate A027 to well 161.0
# Transfer 1.0 µL from barcode_plate A027 to well 162.0
# Transfer 1.0 µL from barcode_plate A027 to well 163.0
# Transfer 1.0 µL from barcode_plate A027 to well 164.0
# Transfer 1.0 µL from barcode_plate A027 to well 165.0
# Transfer 1.0 µL from barcode_plate A027 to well 166.0
# Transfer 1.0 µL from barcode_plate A027 to well 167.0
# Transfer 1.0 µL from barcode_plate A027 to well 168.0
# Transfer 1.0 µL from barcode_plate A027 to well 160.0
# Transfer 1.0 µL from barcode_plate A027 to well 169.0
# Transfer 1.0 µL from barcode_plate A027 to well 171.0
# Transfer 1.0 µL from barcode_plate A027 to well 172.0
# Transfer 1.0 µL from barcode_plate A027 to well 173.0
# Transfer 1.0 µL from barcode_plate A027 to well 174.0
# Transfer 1.0 µL from barcode_plate A027 to well 175.0
# Transfer 1.0 µL from barcode_plate A027 to well 176.0
# Transfer 1.0 µL from barcode_plate A027 to well 177.0
# Transfer 1.0 µL from barcode_plate A027 to well 178.0
# Transfer 1.0 µL from barcode_plate A027 to well 170.0
# Transfer 1.0 µL from barcode_plate A027 to well 180.0
# Transfer 1.0 µL from barcode_plate A027 to well 159.0
# Transfer 1.0 µL from barcode_plate A027 to well 157.0
# Transfer 1.0 µL from barcode_plate A027 to well 139.0
# Transfer 1.0 µL from barcode_plate A027 to well 140.0
# Transfer 1.0 µL from barcode_plate A027 to well 141.0
# Transfer 1.0 µL from barcode_plate A027 to well 142.0
# Transfer 1.0 µL from barcode_plate A027 to well 143.0
# Transfer 1.0 µL from barcode_plate A027 to well 144.0
# Transfer 1.0 µL from barcode_plate A027 to well 145.0
# Transfer 1.0 µL from barcode_plate A027 to well 146.0
# Transfer 1.0 µL from barcode_plate A027 to well 158.0
# Transfer 1.0 µL from barcode_plate A027 to well 147.0
# Transfer 1.0 µL from barcode_plate A027 to well 149.0
# Transfer 1.0 µL from barcode_plate A027 to well 150.0
# Transfer 1.0 µL from barcode_plate A027 to well 151.0
# Transfer 1.0 µL from barcode_plate A027 to well 152.0
# Transfer 1.0 µL from barcode_plate A027 to well 153.0
# Transfer 1.0 µL from barcode_plate A027 to well 154.0
# Transfer 1.0 µL from barcode_plate A027 to well 155.0
# Transfer 1.0 µL from barcode_plate A027 to well 156.0
# Transfer 1.0 µL from barcode_plate A027 to well 148.0
# Transfer 1.0 µL from barcode_plate A027 to well 266.0
