# %%
from io import StringIO
from sqlalchemy import create_engine
import pandas

# %%
engine = create_engine('sqlite:///neat.db')
df = pandas.read_sql_table('sequencing', engine.connect())

# %%
for plate_map in df.plate_map:
    print(plate_map)
#     pt_map = pandas.read_csv(StringIO(plate_map),sep='\s+')
# pt_map
# Out:
#     sample_name forward_primer reverse_primer
# A01  sample_A01             t7         t7term
# B01         NaN            NaN            NaN
# C01  sample_C01             t7         t7term
# D01         NaN            NaN            NaN
# E01  sample_E01             t7         t7term
# F01         NaN            NaN            NaN
# G01  sample_G01             t7         t7term
# H01         NaN            NaN            NaN
# I01  sample_I01             t7         t7term
# J01         NaN            NaN            NaN
# K01  sample_K01             t7         t7term
# L01         NaN            NaN            NaN
# M01         NaN            NaN            NaN
# N01         NaN            NaN            NaN
# O01         NaN            NaN            NaN
# P01         NaN            NaN            NaN
# A02         NaN            NaN            NaN
# B02         NaN            NaN            NaN
# C02         NaN            NaN            NaN
# ...
